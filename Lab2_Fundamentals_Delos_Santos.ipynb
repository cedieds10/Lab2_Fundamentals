# %%
# [CELL 1] CONFIGURATION
ENGINEER = "Delos_Santos"
STUDENT_ID = "TUPM-25-0068"

# Derivation: Extract the last digit to act as your Logic Seed 
SEED_NUM = int(STUDENT_ID[-8])

print(f"System Initialized for: {ENGINEER}")
print(f"Algorithm Seed Value: {SEED_NUM}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       3 STUDENT_ID = "TUPM-25-0068"
#       5 # Derivation: Extract the last digit to act as your Logic Seed
# ----> 6 SEED_NUM = int(STUDENT_ID[-8])
#       8 print(f"System Initialized for: {ENGINEER}")
#       9 print(f"Algorithm Seed Value: {SEED_NUM}")
#
# ValueError: invalid literal for int() with base 10: '-'
